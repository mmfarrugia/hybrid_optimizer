# %%
import os
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import sys
#import ffmpeg
from matplotlib import animation, rc
from IPython.display import HTML, Image

src_dir = os.path.abspath("/home/mmfarrugia/repos/optimization/hybrid_optimizer")
sys.path.append(src_dir)

from hybrid_optimizer import PSO_GA
import example_funcs

# %% [markdown]
# Himmelblau's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.himmelblau, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Rosenbrock's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.rosenbrock, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Beale's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.beale, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Goldstein-Price's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.goldstein, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Booth's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.booth, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Bukin's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.bukin6, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Matyas's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.matyas, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Three Hump Camel's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.threehump, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Easom's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.easom, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Sphere  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.sphere, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Rastrigin's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.rastrigin, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %% [markdown]
# Styblinski-Tang's  objective function
#
#     Only takes two dimensions and has a four equal global minimums
#      of zero at :code:`f([3.0,2.0])`, :code:`f([-2.805118,3.131312])`,
#      :code:`f([-3.779310,-3.283186])`, and :code:`f([3.584428,-1.848126])`.
#     Its coordinates are bounded within :code:`[-5,5]`.
#
#     Best visualized with the full domain and a range of :code:`[0,1000]`

# %%
ho = PSO_GA(example_funcs.styblinski_tang, transform_func=False, n_dim=2, lb=[-5., -5.], ub = [5., 5.], max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
# Out:
# best_x is  [ 3.58413436 -1.84831322] best_y is [5.41975268e-06]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.himmelblau, limits=[(-5,5), (-5,5)])
#Adjust figure limits
d = Designer(limits=[(-5,5), (-5,5), (0,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d);
plt.show()

# %%
ho = PSO_GA(example_funcs.sq_obj_func, n_dim=3, lb=[-1000., -1000., -10000.], ub = [1000., 1000., 1000.], constraint_eq=example_funcs.constraint_eq, constraint_ueq=example_funcs.constraint_ueq)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
print()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.sq_obj_func, limits=[(-1000,1000), (-1000,1000)])
#Adjust figure limits
d = Designer(limits=[(-10,10), (-10,10), (-10,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
# %%capture
#Make animation
animation2D = plot_contour(pos_history=ho.record_value['X'], mesher=m, designer=d, mark=(0,0));
plt.show()

# %%
ho = PSO_GA(func=example_funcs.demo_func, n_dim=3, size_pop=40, max_iter=150, lb=[0, -1, 0.5], ub=[1, 1, 1], w=0.8, c1=0.5, c2=0.5)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)

# %% Plot the result

plt.plot(ho.gbest_y_hist)
plt.show()

# %%
ho = PSO_GA(example_funcs.ackley, lb=[-32., -32.], ub=[32., 32.], n_dim=2, max_iter=50000)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
print()
# Out:
# best_x is  [-0.14807561  0.06175945] best_y is [1.02528927]

# %%
import pandas as pd

Y_history = pd.DataFrame(np.array(ho.record_value['Y']).reshape((-1, ho.size_pop)))
fig, ax = plt.subplots(2, 1)
ax[0].plot(Y_history.index, Y_history.values, '.', color='red')
Y_history.min(axis=1).cummin().plot(kind='line')
plt.show()

# %%
from sko.PSO import PSO
ho = PSO(func=example_funcs.ackley, lb=-32, ub=32, n_dim=2, max_iter=500)
ho.record_mode = True
ho.run()
print('best_x is ', ho.gbest_x, 'best_y is', ho.gbest_y)
plt.plot(ho.gbest_y_hist)
plt.show()
print()

# %%
from plotters import plot_cost_history, plot_contour, plot_surface, Mesher, Designer
#Plot the sphere function's mesh for better plots
m = Mesher(func=example_funcs.ps_ackley, limits=[(-10,10), (-10,10)])
#Adjust figure limits
d = Designer(limits=[(-10,10), (-10,10), (-10,10)], label=['x-axis', 'y-axis', 'z-axis'])

# %%
# %%capture
#Make animation
animation2D = plot_contour(pos_history=np.array(ho.record_value['X']), mesher=m, designer=d, mark=(0,0))

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

record_value = ho.record_value
X_list, V_list = record_value['X'], record_value['V']

fig, ax = plt.subplots(1, 1)
ax.set_title('title', loc='center')
line = ax.plot([], [], 'b.')

X_grid, Y_grid = np.meshgrid(np.linspace(-10.0, 10.0, 40), np.linspace(-10.0, 10.0, 40))
Z_grid = example_funcs.ani_ackley2d((X_grid, Y_grid))
ax.contour(X_grid, Y_grid, Z_grid, 30)

ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)



plt.ion()
p = plt.show()



def update_scatter(frame):
    i, j = frame // 10, frame % 10
    ax.set_title('iter = ' + str(i))
    X_tmp = X_list[i] + V_list[i] * j / 10.0
    plt.setp(line, 'xdata', X_tmp[:, 0], 'ydata', X_tmp[:, 1])
    return line

ani = FuncAnimation(fig, update_scatter, blit=True, interval=25, frames=ho.max_iter)
plt.show()

# %%
#Enables us to view it in a Jupyter Notebook
animation2D.save('plot0.gif', writer='imagemagick', fps=10)
Image(url='plot0.gif')
#html2d = HTML(Ani2D.to_html5_video());
#rc('animation', html='html5');
#Ani2D

# %%
# %%capture
pos_history_3d = m.compute_history_3d(optimizer.pos_history) #preprocessing
animation3d = plot_surface(pos_history=pos_history_3d, mesher=m, designer=d, mark=(0,0,0))

# %%
animation3d.save('plot1.gif', writer='imagemagick', fps=10)
Image(url='plot1.gif')
